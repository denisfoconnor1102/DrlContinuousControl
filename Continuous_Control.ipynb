# %% [markdown]
# # Continuous Control
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.18 which is incompatible.

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726671e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agents while they are training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
# Issues with this on retraining where it causes an Errno 32 Broken Pipe
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agents while they are training.  However, **_after training the agents_**, you can download the saved model weights to watch the agents on your own machine!

# %%
from collections import deque
from ddpg_agent import Agent
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def ddpg(n_episodes=1000, max_t=1000, print_every=10):
    
    agent = Agent(state_size=state_size, action_size=action_size, random_seed=10)
    scores_deque = deque(maxlen=100)
    scores = []
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        print("\nNot stuck on reset!")
        state = env_info.vector_observations[0]
        agent.reset()
        score = 0
        for t in range(max_t):
            action = agent.act(state)
            env_info = env.step(action)[brain_name]
            next_state = env_info.vector_observations[0]
            reward = env_info.rewards[0]
            done = env_info.local_done[0]
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if np.any(done):
                break 
        scores_deque.append(score)
        scores.append(score)
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)), end="")
        
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
        if i_episode % 100 == 0:
#             torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
#             torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            if np.mean(scores_deque) >= 30:
                print('\rEnvironment solved in {} episodes\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
                torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
                torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
                return scores
    return scores

scores = ddpg()

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Not stuck on reset!
# Episode 1	Average Score: 1.01
# Not stuck on reset!
# Episode 2	Average Score: 1.16
# Not stuck on reset!
# Episode 3	Average Score: 1.03
# Not stuck on reset!
# Episode 4	Average Score: 1.03
# Not stuck on reset!
# Episode 5	Average Score: 0.93
# Not stuck on reset!
# Episode 6	Average Score: 0.95
# Not stuck on reset!
# Episode 7	Average Score: 0.88
# Not stuck on reset!
# Episode 8	Average Score: 0.79
# Not stuck on reset!
# Episode 9	Average Score: 0.76
# Not stuck on reset!
# Episode 10	Average Score: 0.72
#
# Not stuck on reset!
# Episode 11	Average Score: 0.67
# Not stuck on reset!
# Episode 12	Average Score: 0.77
# Not stuck on reset!
# Episode 13	Average Score: 0.71
# Not stuck on reset!
# Episode 14	Average Score: 0.74
# Not stuck on reset!
# Episode 15	Average Score: 1.07
# Not stuck on reset!
# Episode 16	Average Score: 1.14
# Not stuck on reset!
# Episode 17	Average Score: 1.17
# Not stuck on reset!
# Episode 18	Average Score: 1.17
# Not stuck on reset!
# Episode 19	Average Score: 1.18
# Not stuck on reset!
# Episode 20	Average Score: 1.19
#
# Not stuck on reset!
# Episode 21	Average Score: 1.17
# Not stuck on reset!
# Episode 22	Average Score: 1.21
# Not stuck on reset!
# Episode 23	Average Score: 1.34
# Not stuck on reset!
# Episode 24	Average Score: 1.39
# Not stuck on reset!
# Episode 25	Average Score: 1.37
# Not stuck on reset!
# Episode 26	Average Score: 1.36
# Not stuck on reset!
# Episode 27	Average Score: 1.35
# Not stuck on reset!
# Episode 28	Average Score: 1.36
# Not stuck on reset!
# Episode 29	Average Score: 1.38
# Not stuck on reset!
# Episode 30	Average Score: 1.43
#
# Not stuck on reset!
# Episode 31	Average Score: 1.47
# Not stuck on reset!
# Episode 32	Average Score: 1.47
# Not stuck on reset!
# Episode 33	Average Score: 1.46
# Not stuck on reset!
# Episode 34	Average Score: 1.70
# Not stuck on reset!
# Episode 35	Average Score: 1.73
# Not stuck on reset!
# Episode 36	Average Score: 1.81
# Not stuck on reset!
# Episode 37	Average Score: 1.82
# Not stuck on reset!
# Episode 38	Average Score: 1.86
# Not stuck on reset!
# Episode 39	Average Score: 1.93
# Not stuck on reset!
# Episode 40	Average Score: 1.98
#
# Not stuck on reset!
# Episode 41	Average Score: 1.98
# Not stuck on reset!
# Episode 42	Average Score: 2.01
# Not stuck on reset!
# Episode 43	Average Score: 2.07
# Not stuck on reset!
# Episode 44	Average Score: 2.06
# Not stuck on reset!
# Episode 45	Average Score: 2.09
# Not stuck on reset!
# Episode 46	Average Score: 2.15
# Not stuck on reset!
# Episode 47	Average Score: 2.20
# Not stuck on reset!
# Episode 48	Average Score: 2.26
# Not stuck on reset!
# Episode 49	Average Score: 2.30
# Not stuck on reset!
# Episode 50	Average Score: 2.33
#
# Not stuck on reset!
# Episode 51	Average Score: 2.40
# Not stuck on reset!
# Episode 52	Average Score: 2.43
# Not stuck on reset!
# Episode 53	Average Score: 2.48
# Not stuck on reset!
# Episode 54	Average Score: 2.52
# Not stuck on reset!
# Episode 55	Average Score: 2.57
# Not stuck on reset!
# Episode 56	Average Score: 2.58
# Not stuck on reset!
# Episode 57	Average Score: 2.68
# Not stuck on reset!
# Episode 58	Average Score: 2.72
# Not stuck on reset!
# Episode 59	Average Score: 2.75
# Not stuck on reset!
# Episode 60	Average Score: 2.80
#
# Not stuck on reset!
# Episode 61	Average Score: 2.80
# Not stuck on reset!
# Episode 62	Average Score: 2.85
# Not stuck on reset!
# Episode 63	Average Score: 2.87
# Not stuck on reset!
# Episode 64	Average Score: 2.84
# Not stuck on reset!
# Episode 65	Average Score: 2.84
# Not stuck on reset!
# Episode 66	Average Score: 2.89
# Not stuck on reset!
# Episode 67	Average Score: 2.91
# Not stuck on reset!
# Episode 68	Average Score: 2.91
# Not stuck on reset!
# Episode 69	Average Score: 2.94
# Not stuck on reset!
# Episode 70	Average Score: 2.98
#
# Not stuck on reset!
# Episode 71	Average Score: 3.02
# Not stuck on reset!
# Episode 72	Average Score: 3.08
# Not stuck on reset!
# Episode 73	Average Score: 3.15
# Not stuck on reset!
# Episode 74	Average Score: 3.14
# Not stuck on reset!
# Episode 75	Average Score: 3.22
# Not stuck on reset!
# Episode 76	Average Score: 3.25
# Not stuck on reset!
# Episode 77	Average Score: 3.30
# Not stuck on reset!
# Episode 78	Average Score: 3.32
# Not stuck on reset!
# Episode 79	Average Score: 3.39
# Not stuck on reset!
# Episode 80	Average Score: 3.42
#
# Not stuck on reset!
# Episode 81	Average Score: 3.48
# Not stuck on reset!
# Episode 82	Average Score: 3.49
# Not stuck on reset!
# Episode 83	Average Score: 3.52
# Not stuck on reset!
# Episode 84	Average Score: 3.51
# Not stuck on reset!
# Episode 85	Average Score: 3.53
# Not stuck on reset!
# Episode 86	Average Score: 3.56
# Not stuck on reset!
# Episode 87	Average Score: 3.59
# Not stuck on reset!
# Episode 88	Average Score: 3.64
# Not stuck on reset!
# Episode 89	Average Score: 3.75
# Not stuck on reset!
# Episode 90	Average Score: 3.84
#
# Not stuck on reset!
# Episode 91	Average Score: 3.86
# Not stuck on reset!
# Episode 92	Average Score: 3.92
# Not stuck on reset!
# Episode 93	Average Score: 4.10
# Not stuck on reset!
# Episode 94	Average Score: 4.17
# Not stuck on reset!
# Episode 95	Average Score: 4.22
# Not stuck on reset!
# Episode 96	Average Score: 4.29
# Not stuck on reset!
# Episode 97	Average Score: 4.36
# Not stuck on reset!
# Episode 98	Average Score: 4.38
# Not stuck on reset!
# Episode 99	Average Score: 4.43
# Not stuck on reset!
# Episode 100	Average Score: 4.48
#
# Not stuck on reset!
# Episode 101	Average Score: 4.64
# Not stuck on reset!
# Episode 102	Average Score: 4.77
# Not stuck on reset!
# Episode 103	Average Score: 4.79
# Not stuck on reset!
# Episode 104	Average Score: 4.97
# Not stuck on reset!
# Episode 105	Average Score: 5.13
# Not stuck on reset!
# Episode 106	Average Score: 5.23
# Not stuck on reset!
# Episode 107	Average Score: 5.38
# Not stuck on reset!
# Episode 108	Average Score: 5.43
# Not stuck on reset!
# Episode 109	Average Score: 5.51
# Not stuck on reset!
# Episode 110	Average Score: 5.63
#
# Not stuck on reset!
# Episode 111	Average Score: 5.77
# Not stuck on reset!
# Episode 112	Average Score: 5.90
# Not stuck on reset!
# Episode 113	Average Score: 6.09
# Not stuck on reset!
# Episode 114	Average Score: 6.16
# Not stuck on reset!
# Episode 115	Average Score: 6.26
# Not stuck on reset!
# Episode 116	Average Score: 6.30
# Not stuck on reset!
# Episode 117	Average Score: 6.44
# Not stuck on reset!
# Episode 118	Average Score: 6.53
# Not stuck on reset!
# Episode 119	Average Score: 6.70
# Not stuck on reset!
# Episode 120	Average Score: 6.82
#
# Not stuck on reset!
# Episode 121	Average Score: 6.93
# Not stuck on reset!
# Episode 122	Average Score: 7.15
# Not stuck on reset!
# Episode 123	Average Score: 7.18
# Not stuck on reset!
# Episode 124	Average Score: 7.40
# Not stuck on reset!
# Episode 125	Average Score: 7.54
# Not stuck on reset!
# Episode 126	Average Score: 7.80
# Not stuck on reset!
# Episode 127	Average Score: 8.08
# Not stuck on reset!
# Episode 128	Average Score: 8.22
# Not stuck on reset!
# Episode 129	Average Score: 8.36
# Not stuck on reset!
# Episode 130	Average Score: 8.41
#
# Not stuck on reset!
# Episode 131	Average Score: 8.55
# Not stuck on reset!
# Episode 132	Average Score: 8.64
# Not stuck on reset!
# Episode 133	Average Score: 8.83
# Not stuck on reset!
# Episode 134	Average Score: 9.01
# Not stuck on reset!
# Episode 135	Average Score: 9.26
# Not stuck on reset!
# Episode 136	Average Score: 9.44
# Not stuck on reset!
# Episode 137	Average Score: 9.65
# Not stuck on reset!
# Episode 138	Average Score: 9.88
# Not stuck on reset!
# Episode 139	Average Score: 10.09
# Not stuck on reset!
# Episode 140	Average Score: 10.33
#
# Not stuck on reset!
# Episode 141	Average Score: 10.54
# Not stuck on reset!
# Episode 142	Average Score: 10.85
# Not stuck on reset!
# Episode 143	Average Score: 11.19
# Not stuck on reset!
# Episode 144	Average Score: 11.37
# Not stuck on reset!
# Episode 145	Average Score: 11.47
# Not stuck on reset!
# Episode 146	Average Score: 11.73
# Not stuck on reset!
# Episode 147	Average Score: 12.06
# Not stuck on reset!
# Episode 148	Average Score: 12.36
# Not stuck on reset!
# Episode 149	Average Score: 12.58
# Not stuck on reset!
# Episode 150	Average Score: 12.85
#
# Not stuck on reset!
# Episode 151	Average Score: 12.98
# Not stuck on reset!
# Episode 152	Average Score: 13.34
# Not stuck on reset!
# Episode 153	Average Score: 13.65
# Not stuck on reset!
# Episode 154	Average Score: 13.82
# Not stuck on reset!
# Episode 155	Average Score: 14.11
# Not stuck on reset!
# Episode 156	Average Score: 14.20
# Not stuck on reset!
# Episode 157	Average Score: 14.33
# Not stuck on reset!
# Episode 158	Average Score: 14.51
# Not stuck on reset!
# Episode 159	Average Score: 14.79
# Not stuck on reset!
# Episode 160	Average Score: 15.09
#
# Not stuck on reset!
# Episode 161	Average Score: 15.36
# Not stuck on reset!
# Episode 162	Average Score: 15.61
# Not stuck on reset!
# Episode 163	Average Score: 15.92
# Not stuck on reset!
# Episode 164	Average Score: 16.18
# Not stuck on reset!
# Episode 165	Average Score: 16.45
# Not stuck on reset!
# Episode 166	Average Score: 16.71
# Not stuck on reset!
# Episode 167	Average Score: 17.05
# Not stuck on reset!
# Episode 168	Average Score: 17.40
# Not stuck on reset!
# Episode 169	Average Score: 17.73
# Not stuck on reset!
# Episode 170	Average Score: 18.00
#
# Not stuck on reset!
# Episode 171	Average Score: 18.30
# Not stuck on reset!
# Episode 172	Average Score: 18.59
# Not stuck on reset!
# Episode 173	Average Score: 18.90
# Not stuck on reset!
# Episode 174	Average Score: 19.09
# Not stuck on reset!
# Episode 175	Average Score: 19.38
# Not stuck on reset!
# Episode 176	Average Score: 19.57
# Not stuck on reset!
# Episode 177	Average Score: 19.77
# Not stuck on reset!
# Episode 178	Average Score: 19.87
# Not stuck on reset!
# Episode 179	Average Score: 19.94
# Not stuck on reset!
# Episode 180	Average Score: 20.23
#
# Not stuck on reset!
# Episode 181	Average Score: 20.47
# Not stuck on reset!
# Episode 182	Average Score: 20.80
# Not stuck on reset!
# Episode 183	Average Score: 21.08
# Not stuck on reset!
# Episode 184	Average Score: 21.43
# Not stuck on reset!
# Episode 185	Average Score: 21.73
# Not stuck on reset!
# Episode 186	Average Score: 22.04
# Not stuck on reset!
# Episode 187	Average Score: 22.37
# Not stuck on reset!
# Episode 188	Average Score: 22.68
# Not stuck on reset!
# Episode 189	Average Score: 22.94
# Not stuck on reset!
# Episode 190	Average Score: 23.14
#
# Not stuck on reset!
# Episode 191	Average Score: 23.42
# Not stuck on reset!
# Episode 192	Average Score: 23.65
# Not stuck on reset!
# Episode 193	Average Score: 23.81
# Not stuck on reset!
# Episode 194	Average Score: 24.07
# Not stuck on reset!
# Episode 195	Average Score: 24.32
# Not stuck on reset!
# Episode 196	Average Score: 24.61
# Not stuck on reset!
# Episode 197	Average Score: 24.86
# Not stuck on reset!
# Episode 198	Average Score: 24.99
# Not stuck on reset!
# Episode 199	Average Score: 25.18
# Not stuck on reset!
# Episode 200	Average Score: 25.47
#
# Not stuck on reset!
# Episode 201	Average Score: 25.67
# Not stuck on reset!
# Episode 202	Average Score: 25.91
# Not stuck on reset!
# Episode 203	Average Score: 26.04
# Not stuck on reset!
# Episode 204	Average Score: 26.23
# Not stuck on reset!
# Episode 205	Average Score: 26.43
# Not stuck on reset!
# Episode 206	Average Score: 26.72
# Not stuck on reset!
# Episode 207	Average Score: 26.95
# Not stuck on reset!
# Episode 208	Average Score: 27.24
# Not stuck on reset!
# Episode 209	Average Score: 27.54
# Not stuck on reset!
# Episode 210	Average Score: 27.80
#
# Not stuck on reset!
# Episode 211	Average Score: 28.05
# Not stuck on reset!
# Episode 212	Average Score: 28.27
# Not stuck on reset!
# Episode 213	Average Score: 28.33
# Not stuck on reset!
# Episode 214	Average Score: 28.57
# Not stuck on reset!
# Episode 215	Average Score: 28.73
# Not stuck on reset!
# Episode 216	Average Score: 29.04
# Not stuck on reset!
# Episode 217	Average Score: 29.26
# Not stuck on reset!
# Episode 218	Average Score: 29.48
# Not stuck on reset!
# Episode 219	Average Score: 29.67
# Not stuck on reset!
# Episode 220	Average Score: 29.91
#
# Not stuck on reset!
# Episode 221	Average Score: 30.14
# Not stuck on reset!
# Episode 222	Average Score: 30.25
# Not stuck on reset!
# Episode 223	Average Score: 30.54
# Not stuck on reset!
# Episode 224	Average Score: 30.65
# Not stuck on reset!
# Episode 225	Average Score: 30.88
# Not stuck on reset!
# Episode 226	Average Score: 30.97
# Not stuck on reset!
# Episode 227	Average Score: 31.03
# Not stuck on reset!
# Episode 228	Average Score: 30.97
# Not stuck on reset!
# Episode 229	Average Score: 31.06
# Not stuck on reset!
# Episode 230	Average Score: 31.19
#
# Not stuck on reset!
# Episode 231	Average Score: 31.20
# Not stuck on reset!
# Episode 232	Average Score: 31.41
# Not stuck on reset!
# Episode 233	Average Score: 31.61
# Not stuck on reset!
# Episode 234	Average Score: 31.68
# Not stuck on reset!
# Episode 235	Average Score: 31.73
# Not stuck on reset!
# Episode 236	Average Score: 31.87
# Not stuck on reset!
# Episode 237	Average Score: 31.91
# Not stuck on reset!
# Episode 238	Average Score: 32.00
# Not stuck on reset!
# Episode 239	Average Score: 32.11
# Not stuck on reset!
# Episode 240	Average Score: 32.17
#
# Not stuck on reset!
# Episode 241	Average Score: 32.32
# Not stuck on reset!
# Episode 242	Average Score: 32.30
# Not stuck on reset!
# Episode 243	Average Score: 32.28
# Not stuck on reset!
# Episode 244	Average Score: 32.23
# Not stuck on reset!
# Episode 245	Average Score: 32.37
# Not stuck on reset!
# Episode 246	Average Score: 32.41
# Not stuck on reset!
# Episode 247	Average Score: 32.37
# Not stuck on reset!
# Episode 248	Average Score: 32.36
# Not stuck on reset!
# Episode 249	Average Score: 32.45
# Not stuck on reset!
# Episode 250	Average Score: 32.54
#
# Not stuck on reset!
# Episode 251	Average Score: 32.64
# Not stuck on reset!
# Episode 252	Average Score: 32.59
# Not stuck on reset!
# Episode 253	Average Score: 32.50
# Not stuck on reset!
# Episode 254	Average Score: 32.62
# Not stuck on reset!
# Episode 255	Average Score: 32.65
# Not stuck on reset!
# Episode 256	Average Score: 32.91
# Not stuck on reset!
# Episode 257	Average Score: 33.09
# Not stuck on reset!
# Episode 258	Average Score: 33.23
# Not stuck on reset!
# Episode 259	Average Score: 33.22
# Not stuck on reset!
# Episode 260	Average Score: 33.14
#
# Not stuck on reset!
# Episode 261	Average Score: 33.08
# Not stuck on reset!
# Episode 262	Average Score: 33.06
# Not stuck on reset!
# Episode 263	Average Score: 32.88
# Not stuck on reset!
# Episode 264	Average Score: 33.01
# Not stuck on reset!
# Episode 265	Average Score: 32.99
# Not stuck on reset!
# Episode 266	Average Score: 33.00
# Not stuck on reset!
# Episode 267	Average Score: 32.91
# Not stuck on reset!
# Episode 268	Average Score: 32.66
# Not stuck on reset!
# Episode 269	Average Score: 32.68
# Not stuck on reset!
# Episode 270	Average Score: 32.54
#
# Not stuck on reset!
# Episode 271	Average Score: 32.46
# Not stuck on reset!
# Episode 272	Average Score: 32.32
# Not stuck on reset!
# Episode 273	Average Score: 32.16
# Not stuck on reset!
# Episode 274	Average Score: 32.21
# Not stuck on reset!
# Episode 275	Average Score: 32.14
# Not stuck on reset!
# Episode 276	Average Score: 32.18
# Not stuck on reset!
# Episode 277	Average Score: 32.26
# Not stuck on reset!
# Episode 278	Average Score: 32.36
# Not stuck on reset!
# Episode 279	Average Score: 32.58
# Not stuck on reset!
# Episode 280	Average Score: 32.59
#
# Not stuck on reset!
# Episode 281	Average Score: 32.61
# Not stuck on reset!
# Episode 282	Average Score: 32.59
# Not stuck on reset!
# Episode 283	Average Score: 32.59
# Not stuck on reset!
# Episode 284	Average Score: 32.48
# Not stuck on reset!
# Episode 285	Average Score: 32.47
# Not stuck on reset!
# Episode 286	Average Score: 32.32
# Not stuck on reset!
# Episode 287	Average Score: 32.18
# Not stuck on reset!
# Episode 288	Average Score: 32.04
# Not stuck on reset!
# Episode 289	Average Score: 31.93
# Not stuck on reset!
# Episode 290	Average Score: 31.86
#
# Not stuck on reset!
# Episode 291	Average Score: 31.87
# Not stuck on reset!
# Episode 292	Average Score: 31.78
# Not stuck on reset!
# Episode 293	Average Score: 31.76
# Not stuck on reset!
# Episode 294	Average Score: 31.76
# Not stuck on reset!
# Episode 295	Average Score: 31.74
# Not stuck on reset!
# Episode 296	Average Score: 31.66
# Not stuck on reset!
# Episode 297	Average Score: 31.58
# Not stuck on reset!
# Episode 298	Average Score: 31.69
# Not stuck on reset!
# Episode 299	Average Score: 31.72
# Not stuck on reset!
# Episode 300	Average Score: 31.66
# Environment solved in 300 episodes	Average Score: 31.66
